# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/J.C/Desktop/Data/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding='latin-1')

# %%
df.head(40)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
df["Area"].nunique()
# Out:
# 49

# %%
print(df["Y2017"].mean())
print(df["Y2017"].std())
# Out:
# 140.9177648602722
# 1671.8623590567995

# %% [markdown]
# ### Grouping Area by Y2017

# %%
df[["Y2017", "Area"]].groupby("Area").sum().sort_values(by="Y2017", ascending=False)
# Out:
#                                   Y2017
# Area
# Nigeria                      1483268.23
# Egypt                         866379.92
# South Africa                  517590.54
# Ethiopia                      448683.76
# Morocco                       388495.36
# Ghana                         337599.06
# Algeria                       325644.27
# United Republic of Tanzania   322616.85
# Kenya                         264660.66
# Sudan                         239931.92
# Cameroon                      232030.43
# Angola                        229159.57
# Côte d'Ivoire                 224599.01
# Uganda                        213950.38
# Malawi                        181098.71
# Mozambique                    161407.98
# Mauritania                    156665.46
# Mali                          149928.33
# Madagascar                    131197.73
# Niger                         126707.58
# Benin                         124771.22
# Tunisia                       124167.20
# ...

# %%
df.groupby("Item")[["Y2015", "Y2018"]].sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
df[["Area", "Y2017"]].groupby("Area").sum().sort_values(by="Y2017", ascending=False)
# Out:
#                                   Y2017
# Area
# Nigeria                      1483268.23
# Egypt                         866379.92
# South Africa                  517590.54
# Ethiopia                      448683.76
# Morocco                       388495.36
# Ghana                         337599.06
# Algeria                       325644.27
# United Republic of Tanzania   322616.85
# Kenya                         264660.66
# Sudan                         239931.92
# Cameroon                      232030.43
# Angola                        229159.57
# Côte d'Ivoire                 224599.01
# Uganda                        213950.38
# Malawi                        181098.71
# Mozambique                    161407.98
# Mauritania                    156665.46
# Mali                          149928.33
# Madagascar                    131197.73
# Niger                         126707.58
# Benin                         124771.22
# Tunisia                       124167.20
# ...

# %%
corr = df.drop(columns=["Area", "Item", "Element", "Unit"]).corr()
import seaborn as sns
sns.heatmap(corr, cmap="Blues", annot=True, cbar=True, square=True)
# Out:
# <Axes: >

# %%
df.groupby("Area")["Y2015"].sum()
# Out:
# Area
# Algeria                         324058.40
# Angola                          209565.67
# Benin                           108181.13
# Botswana                         23024.85
# Burkina Faso                    102701.22
# Cabo Verde                       14538.93
# Cameroon                        225220.72
# Central African Republic         28885.34
# Chad                             65835.88
# Comoros                             41.34
# Congo                            40255.51
# Côte d'Ivoire                   211591.29
# Djibouti                         23690.16
# Egypt                           868218.73
# Eswatini                         54072.07
# Ethiopia                        429139.33
# Ethiopia PDR                         0.00
# Gabon                            28367.30
# Gambia                           19665.39
# Ghana                           311092.13
# Guinea                           92803.39
# Guinea-Bissau                    17990.06
# ...

# %% [markdown]
# ### Number and percentage of missing data in 2014

# %%
df["Y2014"].isna().sum()
# Out:
# 1589

# %%
round((df["Y2014"].isna().sum() / df["Y2014"].count()), 3 ) * 100
# Out:
# 2.7

# %%
df.groupby("Element")["Y2017"].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %% [markdown]
# ###

# %% [markdown]
# ### Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
print(df.groupby("Element")[["Y2017", "Y2014", "Y2016", "Y2015"]].sum())
# print(df.groupby("Element")["Y2014"].sum())
# Out:
#                                              Y2017       Y2014       Y2016  \
# Element
# Domestic supply quantity                2088198.10  1996716.35  2044842.70
# Export Quantity                          182338.80   150020.64   151920.46
# Fat supply quantity (g/capita/day)        10253.84    10225.56    10102.77
# Feed                                     223705.68   216927.89   228958.65
# Food                                    1258888.28  1212332.49  1247022.17
# Food supply (kcal/capita/day)            454681.00   454257.00   451810.00
# Food supply quantity (kg/capita/yr)       48690.04    49650.63    48985.28
# Import Quantity                          294559.09   274144.48   286582.78
# Losses                                   160614.00   153223.00   157787.00
# Other uses (non-food)                     91645.97    78718.13    69563.68
# Processing                               292836.00   282923.00   280631.00
# ...

# %% [markdown]
# ### What is the total Protein supply quantity in Madagascar in 2015?

# %%
protein = df["Element"] == "Protein supply quantity (g/capita/day)" 
mad = df["Area"] == "Madagascar"

df_1  = df[protein & mad]
df_1.head()
# Out:
#        Area Code        Area  Item Code                      Item  \
# 30718        129  Madagascar       2901               Grand Total
# 30721        129  Madagascar       2903          Vegetal Products
# 30724        129  Madagascar       2941           Animal Products
# 30740        129  Madagascar       2905  Cereals - Excluding Beer
# 30756        129  Madagascar       2511        Wheat and products
#
#        Element Code                                 Element          Unit  \
# 30718           674  Protein supply quantity (g/capita/day)  g/capita/day
# 30721           674  Protein supply quantity (g/capita/day)  g/capita/day
# 30724           674  Protein supply quantity (g/capita/day)  g/capita/day
# 30740           674  Protein supply quantity (g/capita/day)  g/capita/day
# 30756           674  Protein supply quantity (g/capita/day)  g/capita/day
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 30718  44.45  43.26  43.35  43.94  44.17
# ...

# %%
df_1[["Area", "Element", "Y2015"]].groupby("Element").sum()
# Out:
#                                                                                      Area  \
# Element
# Protein supply quantity (g/capita/day)  MadagascarMadagascarMadagascarMadagascarMadaga...
#
#                                          Y2015
# Element
# Protein supply quantity (g/capita/day)  173.05

# %% [markdown]
# ### Sum of Processing in 2017

# %%
df.groupby("Element")["Y2017"].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...
